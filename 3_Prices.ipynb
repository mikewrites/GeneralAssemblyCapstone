# %%
import geopandas as gpd
import numpy as np
import json
import pandas as pd

# %%
us = gpd.read_file('Data/US_fixed.shp')

# %%
growth = pd.read_csv('https://www2.census.gov/programs-surveys/popest/datasets/2010-2020/counties/totals/co-est2020-alldata.csv', encoding = 'latin-1')

# %%
growth.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#   CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RNETMIG2011  \
# 0       4779736            4780118          4785514  ...     0.680010
# 1         54571              54582            54761  ...     6.236931
# 2        182265             182263           183121  ...    16.705437
# 3         27457              27454            27325  ...     0.329254
# 4         22915              22904            22858  ...    -4.912927
#
#    RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015  RNETMIG2016  \
# ...

# %%
years = [i for i in range(2010,2021)]

# %%
names = [f'POPESTIMATE{year}' for year in years]

# %%
other = [f'NETMIG{year}' for year in years]

# %%
columns = ['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'COUNTY', 'STNAME', 'CTYNAME',
       'CENSUS2010POP', 'ESTIMATESBASE2010']

# %%
for name in names:
    columns.append(name)
for mi in other:
    columns.append(mi)

# %%
counties = growth[columns]

# %%
intervals = [1,2,3,5, 10]

# %%
for i in intervals:
    col = f'{i} years'
    growth[col] = (growth['POPESTIMATE2020']-growth[f'POPESTIMATE{2020-i}'])/growth[f'POPESTIMATE{2020-i}']

# %%
growth.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#   CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RNETMIG2016  \
# 0       4779736            4780118          4785514  ...     0.854384
# 1         54571              54582            54761  ...     4.954403
# 2        182265             182263           183121  ...    21.436499
# 3         27457              27454            27325  ...   -18.377839
# 4         22915              22904            22858  ...    -0.841769
#
#    RNETMIG2017  RNETMIG2018  RNETMIG2019  RNETMIG2020   1 years   2 years  \
# ...

# %%
one = growth.sort_values('3 years').tail(15)
one
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY          STNAME  \
# 2849      50       4         8     49      53            Utah
# 111       50       4         8      4      21         Arizona
# 2833      50       4         8     49      21            Utah
# 2672      50       3         7     48     209           Texas
# 396       50       3         5     12     131         Florida
# 476       50       3         5     13     157         Georgia
# 2813      50       3         7     48     491           Texas
# 2766      50       3         7     48     397           Texas
# 1934      50       3         5     37      19  North Carolina
# 385       50       3         5     12     109         Florida
# 2078      50       2         4     38     105    North Dakota
# 2696      50       3         7     48     257           Texas
# 2613      50       3         7     48      91           Texas
# 2052      50       2         4     38      53    North Dakota
# ...

# %% [markdown]
# def join(state, county, inter, df = growth):
#     df1 = df.loc[df['STNAME'] == state]
#     df1.set_index('CTYNAME', inplace = True)
#     col = f"{inter} year'
#     return df1.loc['county' ]

# %%
us.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1737905 entries, 0 to 1737904
# Data columns (total 25 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   quadkey     object
#  1   avg_d_kbps  int64
#  2   avg_u_kbps  int64
#  3   avg_lat_ms  int64
#  4   tests       int64
#  5   devices     int64
#  6   index_righ  int64
#  7   STATEFP     object
#  8   COUNTYFP    object
#  9   COUNTYNS    object
#  10  GEOID       object
#  11  NAME        object
#  12  NAMELSAD    object
#  13  LSAD        object
#  14  CLASSFP     object
#  15  MTFCC       object
#  16  CSAFP       object
#  17  CBSAFP      object
#  18  METDIVFP    object
#  19  FUNCSTAT    object
#  20  ALAND       int64
#  21  AWATER      int64
#  22  INTPTLAT    object
#  23  INTPTLON    object
#  24  geometry    geometry
# dtypes: geometry(1), int64(8), object(16)
# memory usage: 331.5+ MB

# %%
us['NAMELSAD']
# Out:
# 0                        Comal County
# 1                        Comal County
# 2                        Comal County
# 3                        Comal County
# 4                        Comal County
#                       ...
# 1737900               Garfield County
# 1737901               Garfield County
# 1737902              McPherson County
# 1737903               Marshall County
# 1737904    Aleutians West Census Area
# Name: NAMELSAD, Length: 1737905, dtype: object

# %%
metros = gpd.read_file('Data/metro_areas.csv')
#states = gpd.read_file('Data/)

# %%
metros.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Metro Area                     125 non-null    object
#  1   Est. 2019 Population           125 non-null    object
#  2   Average Annual Salary          125 non-null    object
#  3   ZORI 2020-06                   125 non-null    object
#  4   Avg Annual Rainfall            125 non-null    object
#  5   Lowest Monthly Avg High Temp   125 non-null    object
#  6   Highest Monthly Avg High Temp  125 non-null    object
#  7   Violent Crime Rate             125 non-null    object
#  8   Property Crime Rate            125 non-null    object
#  9   U.S. News Overall Score        125 non-null    object
#  10  U.S. News State Overall Rank   125 non-null    object
#  11  Nomad Score 2019-12-21T17:00Z  125 non-null    object
# ...

# %%
states = gpd.read_file('Data/state_ranks.csv')

# %%
metpop = pd.read_csv('https://www2.census.gov/programs-surveys/popest/datasets/2010-2020/metro/totals/csa-est2020-alldata.csv', encoding = 'latin-1')

# %%
metpop.columns
# Out:
# Index(['CSA', 'CBSA', 'MDIV', 'STCOU', 'NAME', 'LSAD', 'CENSUS2010POP',
#        'ESTIMATESBASE2010', 'POPESTIMATE2010', 'POPESTIMATE2011',
#        ...
#        'RESIDUAL2011', 'RESIDUAL2012', 'RESIDUAL2013', 'RESIDUAL2014',
#        'RESIDUAL2015', 'RESIDUAL2016', 'RESIDUAL2017', 'RESIDUAL2018',
#        'RESIDUAL2019', 'RESIDUAL2020'],
#       dtype='object', length=107)

# %%
columns = ['CSA', 'CBSA', 'MDIV', 'STCOU', 'NAME', 'LSAD']
mig= [f'NETMIG{year}' for year in years]
for name in names:
    columns.append(name)
for mi in mig:
    columns.append(mi)

# %%
metpop = metpop[columns]

# %%
metpop.head()
# Out:
#    CSA     CBSA  MDIV    STCOU                         NAME  \
# 0  104      NaN   NaN      NaN       Albany-Schenectady, NY
# 1  104  10580.0   NaN      NaN  Albany-Schenectady-Troy, NY
# 2  104  10580.0   NaN  36001.0            Albany County, NY
# 3  104  10580.0   NaN  36083.0        Rensselaer County, NY
# 4  104  10580.0   NaN  36091.0          Saratoga County, NY
#
#                             LSAD  POPESTIMATE2010  POPESTIMATE2011  \
# 0      Combined Statistical Area          1168928          1169287
# 1  Metropolitan Statistical Area           871101           872870
# 2           County or equivalent           304085           304627
# 3           County or equivalent           159342           159606
# 4           County or equivalent           220123           221136
#
#    POPESTIMATE2012  POPESTIMATE2013  ...  NETMIG2011  NETMIG2012  NETMIG2013  \
# 0          1170442          1171438  ...        -896          38         -69
# ...

# %%
prices = pd.read_csv('Data/County_zhvi_uc_sfr_tier_0.33_0.67_sm_sa_month.csv')

# %%
current_prices = prices['2021-10-31']

# %%
current_prices
# Out:
# 0       838224.0
# 1       299379.0
# 2       254593.0
# 3       436614.0
# 4       859724.0
#           ...
# 2816    190904.0
# 2817    276600.0
# 2818    394449.0
# 2819    345172.0
# 2820    364508.0
# Name: 2021-10-31, Length: 2821, dtype: float64

# %%
counties.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#   CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  NETMIG2011  \
# 0       4779736            4780118          4785514  ...        3259
# 1         54571              54582            54761  ...         343
# 2        182265             182263           183121  ...        3088
# 3         27457              27454            27325  ...           9
# 4         22915              22904            22858  ...        -112
#
#    NETMIG2012  NETMIG2013  NETMIG2014  NETMIG2015  NETMIG2016  NETMIG2017  \
# ...

# %%
us.head()
# Out:
#             quadkey  avg_d_kbps  avg_u_kbps  avg_lat_ms  tests  devices  \
# 0  0231301222133033      166797       55407          18     38       10
# 1  0231301222120113        7850        1510          28      4        1
# 2  0231301222301320      116315       13823          22     83       20
# 3  0231301222311121      143093       15049          23     94       25
# 4  0231301222133230      118641       15201          22     36        7
#
#    index_righ STATEFP COUNTYFP  COUNTYNS  ...  MTFCC CSAFP CBSAFP METDIVFP  \
# 0         703      48      091  01383831  ...  G4020   484  41700     None
# 1         703      48      091  01383831  ...  G4020   484  41700     None
# 2         703      48      091  01383831  ...  G4020   484  41700     None
# 3         703      48      091  01383831  ...  G4020   484  41700     None
# 4         703      48      091  01383831  ...  G4020   484  41700     None
#
#   FUNCSTAT       ALAND    AWATER     INTPTLAT      INTPTLON  \
# ...

# %%
abbr = pd.read_csv('Data/stateAbbr.csv')

# %%
abbr.head
# Out:
# <bound method NDFrame.head of                    State  Abbrev Code
# 0                Alabama    Ala.   AL
# 1                 Alaska  Alaska   AK
# 2                Arizona   Ariz.   AZ
# 3               Arkansas    Ark.   AR
# 4             California  Calif.   CA
# 5               Colorado   Colo.   CO
# 6            Connecticut   Conn.   CT
# 7               Delaware    Del.   DE
# 8   District of Columbia    D.C.   DC
# 9                Florida    Fla.   FL
# 10               Georgia     Ga.   GA
# 11                Hawaii  Hawaii   HI
# 12                 Idaho   Idaho   ID
# 13              Illinois    Ill.   IL
# 14               Indiana    Ind.   IN
# 15                  Iowa    Iowa   IA
# 16                Kansas   Kans.   KS
# 17              Kentucky     Ky.   KY
# 18             Louisiana     La.   LA
# 19                 Maine   Maine   ME
# 20              Maryland     Md.   MD
# 21         Massachusetts   Mass.   MA
# 22              Michigan   Mich.   MI
# ...

# %%
abbr.set_index('Code', inplace = True)

# %%
def fullname(value, df = abbr):
    full = df.loc[value , 'State']
    return full
prices['StateName'] = prices['State'].apply(lambda x: fullname(x))

# %%
prices.head()
# Out:
#    RegionID  SizeRank          RegionName RegionType   StateName State  \
# 0      3101         0  Los Angeles County     County  California    CA
# 1       139         1         Cook County     County    Illinois    IL
# 2      1090         2       Harris County     County       Texas    TX
# 3      2402         3     Maricopa County     County     Arizona    AZ
# 4      2841         4    San Diego County     County  California    CA
#
#                               Metro  StateCodeFIPS  MunicipalCodeFIPS  \
# 0    Los Angeles-Long Beach-Anaheim              6                 37
# 1          Chicago-Naperville-Elgin             17                 31
# 2  Houston-The Woodlands-Sugar Land             48                201
# 3           Phoenix-Mesa-Scottsdale              4                 13
# 4                San Diego-Carlsbad              6                 73
#
#    2000-01-31  ...  2021-01-31  2021-02-28  2021-03-31  2021-04-30  \
# ...

# %%
us.columns
# Out:
# Index(['quadkey', 'avg_d_kbps', 'avg_u_kbps', 'avg_lat_ms', 'tests', 'devices',
#        'index_righ', 'STATEFP', 'COUNTYFP', 'COUNTYNS', 'GEOID', 'NAME',
#        'NAMELSAD', 'LSAD', 'CLASSFP', 'MTFCC', 'CSAFP', 'CBSAFP', 'METDIVFP',
#        'FUNCSTAT', 'ALAND', 'AWATER', 'INTPTLAT', 'INTPTLON', 'geometry'],
#       dtype='object')

# %%
us.STATEFP.unique()
# Out:
# array(['48', '17', '21', '29', '22', '13', '06', '05', '36', '12', '47',
#        '18', '09', '33', '04', '28', '27', '08', '24', '39', '41', '16',
#        '34', '37', '02', '26', '01', '53', '25', '72', '19', '42', '54',
#        '23', '55', '45', '31', '15', '35', '40', '44', '51', '66', '30',
#        '49', '32', '46', '20', '60', '10', '56', '11', '50', '78', '38',
#        '69'], dtype=object)

# %%
label = gpd.read_file('https://www2.census.gov/geo/tiger/GENZ2019/shp/cb_2019_us_state_500k.zip')

# %%
labels = label[['STATEFP', 'NAME']].set_index('STATEFP').rename(columns={'NAME':'State'})

# %%
labels.columns
# Out:
# Index(['State'], dtype='object')

# %%
us['STATENAME'] = us['STATEFP'].apply(lambda x: fullname(str(x), df = labels))

# %%
stategrowth = pd.read_csv('Data/nst-est2019-alldata.csv')

# %%
stategrowth.head(15)
# Out:
#     SUMLEV REGION DIVISION  STATE                  NAME  CENSUS2010POP  \
# 0       10      0        0      0         United States      308745538
# 1       20      1        0      0      Northeast Region       55317240
# 2       20      2        0      0        Midwest Region       66927001
# 3       20      3        0      0          South Region      114555744
# 4       20      4        0      0           West Region       71945553
# 5       40      3        6      1               Alabama        4779736
# 6       40      4        9      2                Alaska         710231
# 7       40      4        8      4               Arizona        6392017
# 8       40      3        7      5              Arkansas        2915918
# 9       40      4        9      6            California       37253956
# 10      40      4        8      8              Colorado        5029196
# 11      40      1        1      9           Connecticut        3574097
# ...

# %%
stategrowth = stategrowth.loc[5:]

# %%
stategrowth['totalgrowth'] = stategrowth['POPESTIMATE2019']-stategrowth['POPESTIMATE2010']

# %%
stategrowth['pct_growth'] = stategrowth['totalgrowth']/stategrowth['POPESTIMATE2010']

# %%
stategrowth = stategrowth[['NAME','pct_growth', 'totalgrowth']].set_index('NAME')

# %%
stategrowth.to_csv('Data/Stategrowth.csv')

# %%
stategrowth.head()
# Out:
#             pct_growth  totalgrowth
# NAME
# Alabama       0.024605       117748
# Alaska        0.024702        17635
# Arizona       0.136026       871545
# Arkansas      0.032800        95840
# California    0.058755      2192721

# %%
whole=prices.groupby('StateName').mean()

# %%
whole = whole.join(stategrowth)

# %%
us.columns
# Out:
# Index(['quadkey', 'avg_d_kbps', 'avg_u_kbps', 'avg_lat_ms', 'tests', 'devices',
#        'index_righ', 'STATEFP', 'COUNTYFP', 'COUNTYNS', 'GEOID', 'NAME',
#        'NAMELSAD', 'LSAD', 'CLASSFP', 'MTFCC', 'CSAFP', 'CBSAFP', 'METDIVFP',
#        'FUNCSTAT', 'ALAND', 'AWATER', 'INTPTLAT', 'INTPTLON', 'geometry',
#        'STATENAME'],
#       dtype='object')

# %%
statespeed = us[['avg_d_kbps', 'avg_u_kbps', 'avg_lat_ms', 'STATENAME']].groupby('STATENAME').mean()

# %%
whole = whole.join(statespeed)

# %%
whole.head()
# Out:
#                 RegionID     SizeRank  StateCodeFIPS  MunicipalCodeFIPS  \
# StateName
# Alabama      1617.584615  1268.400000            1.0          67.092308
# Alaska      89846.500000  1388.250000            2.0         123.375000
# Arizona      1376.533333   728.333333            4.0          13.866667
# Arkansas     1602.175676  1707.554054            5.0          75.297297
# California   1792.948276   687.034483            6.0          58.000000
#
#                2000-01-31     2000-02-29     2000-03-31     2000-04-30  \
# StateName
# Alabama     105493.500000  105693.250000  105862.750000  103730.000000
# Alaska      170388.000000  170777.000000  170855.000000  171058.000000
# Arizona     110560.000000  110748.818182  110933.909091  111359.181818
# Arkansas     66486.090909   66634.840909   66759.272727   67020.113636
# California  254575.000000  255776.517241  257239.586207  260460.068966
#
#                2000-05-31     2000-06-30  ...     2021-06-30     2021-07-31  \
# ...

# %%
whole.to_csv('Data/WholeCountry.csv')

# %%
counties=counties.loc[growth['COUNTY'] !=0 ]

# %%
countieslg = counties.loc[counties['POPESTIMATE2010']>10000]

# %%
countieslg.columns
# Out:
# Index(['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'COUNTY', 'STNAME', 'CTYNAME',
#        'CENSUS2010POP', 'ESTIMATESBASE2010', 'POPESTIMATE2010',
#        'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013',
#        'POPESTIMATE2014', 'POPESTIMATE2015', 'POPESTIMATE2016',
#        'POPESTIMATE2017', 'POPESTIMATE2018', 'POPESTIMATE2019',
#        'POPESTIMATE2020', 'NETMIG2010', 'NETMIG2011', 'NETMIG2012',
#        'NETMIG2013', 'NETMIG2014', 'NETMIG2015', 'NETMIG2016', 'NETMIG2017',
#        'NETMIG2018', 'NETMIG2019', 'NETMIG2020'],
#       dtype='object')

# %%
countieslg['totalgrowth'] = countieslg['POPESTIMATE2019']-countieslg['POPESTIMATE2010']
# Out:
# /opt/conda/envs/rapids/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
countieslg['pctgrowth'] = countieslg['totalgrowth']/countieslg['POPESTIMATE2010']
# Out:
# /opt/conda/envs/rapids/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
countieslg.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#   CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  NETMIG2013  \
# 1         54571              54582            54761  ...        -207
# 2        182265             182263           183121  ...        4415
# 3         27457              27454            27325  ...        -219
# 4         22915              22904            22858  ...        -131
# 5         57322              57322            57372  ...         -16
#
#    NETMIG2014  NETMIG2015  NETMIG2016  NETMIG2017  NETMIG2018  NETMIG2019  \
# ...

# %%
propgrowthcty= countieslg.sort_values('pctgrowth').tail(100)

# %%
propgrowthcty
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY          STNAME  \
# 1956      50       3         5     37      63  North Carolina
# 2587      50       3         7     48      39           Texas
# 2531      50       3         6     47     119       Tennessee
# 605       50       4         8     16      81           Idaho
# 42        50       3         6      1      83         Alabama
# ...      ...     ...       ...    ...     ...             ...
# 390       50       3         5     12     119         Florida
# 2613      50       3         7     48      91           Texas
# 2848      50       4         8     49      51            Utah
# 2672      50       3         7     48     209           Texas
# 2078      50       2         4     38     105    North Dakota
#
#                CTYNAME CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# 1956     Durham County        267587             269998           271366  ...
# ...

# %%
absgrowthcty = countieslg.sort_values('totalgrowth').tail(100)

# %%
absgrowthcty
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY          STNAME  \
# 1956      50       3         5     37      63  North Carolina
# 1710      50       2         4     31      55        Nebraska
# 1885      50       1         2     36      47        New York
# 1295      50       2         3     26      81        Michigan
# 2565      50       3         6     47     187       Tennessee
# ...      ...     ...       ...    ...     ...             ...
# 2787      50       3         7     48     439           Texas
# 3018      50       4         9     53      33      Washington
# 1778      50       4         8     32       3          Nevada
# 2668      50       3         7     48     201           Texas
# 107       50       4         8      4      13         Arizona
#
#                 CTYNAME CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# 1956      Durham County        267587             269998           271366
# ...

# %%
sect = pd.merge(propgrowthcty, absgrowthcty, how='inner')

# %%
sect
# Out:
#     SUMLEV  REGION  DIVISION  STATE  COUNTY          STNAME  \
# 0       50       3         5     37      63  North Carolina
# 1       50       3         7     48      39           Texas
# 2       50       3         5     12      21         Florida
# 3       50       3         5     12      57         Florida
# 4       50       3         5     12     105         Florida
# 5       50       4         8      8      31        Colorado
# 6       50       3         5     37     119  North Carolina
# 7       50       3         5     12      95         Florida
# 8       50       4         8      4      21         Arizona
# 9       50       2         3     18      57         Indiana
# 10      50       4         8     49      49            Utah
# 11      50       4         8     16       1           Idaho
# 12      50       4         8      8      35        Colorado
# 13      50       3         5     37     183  North Carolina
# 14      50       3         5     12      69         Florida
# ...

# %%
us.columns
# Out:
# Index(['quadkey', 'avg_d_kbps', 'avg_u_kbps', 'avg_lat_ms', 'tests', 'devices',
#        'index_righ', 'STATEFP', 'COUNTYFP', 'COUNTYNS', 'GEOID', 'NAME',
#        'NAMELSAD', 'LSAD', 'CLASSFP', 'MTFCC', 'CSAFP', 'CBSAFP', 'METDIVFP',
#        'FUNCSTAT', 'ALAND', 'AWATER', 'INTPTLAT', 'INTPTLON', 'geometry',
#        'STATENAME'],
#       dtype='object')

# %%
us[['avg_d_kbps', 'avg_u_kbps', 'avg_lat_ms','NAME', 'STATENAME']].groupby(['STATENAME', 'NAME']).mean()
# Out:
#                          avg_d_kbps    avg_u_kbps  avg_lat_ms
# STATENAME NAME
# Alabama   Autauga     111177.437500  40532.955000   47.407500
#           Baldwin      77741.209245  30603.861829   74.131213
#           Barbour      66922.000000   9129.917293   87.721805
#           Bibb         42270.964539  28659.184397   76.666667
#           Blount       60889.521204  21384.781122   47.896033
# ...                             ...           ...         ...
# Wyoming   Sweetwater   51271.542636  12741.643411   34.139535
#           Teton        69657.226506  25032.551807   62.621687
#           Uinta        51310.520000  20876.273333   36.193333
#           Washakie     52312.328125  20581.203125   24.125000
#           Weston       56062.338462  11086.276923   80.461538
#
# [3213 rows x 3 columns]

# %%
states = ['Washington', 'North Dakota', 'Arizona', 'Idaho', 'Florida', 'Nevada', 'Colorado', 'Texas', 'Utah']

# %%
for state in states:
